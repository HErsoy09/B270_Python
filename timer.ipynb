# %%
import time
def countdown_timer(minutes):
    total_seconds = minutes * 60
    for remaining in range(total_seconds, -1, -1):
        mins, secs = divmod(remaining, 60)
        time_format = f"{mins:02d}:{secs:02d}"
        print(time_format, end='\r', flush=True)
        time.sleep(1)
# 10 dakikalık geri sayım
countdown_timer(10)
# Out:
# 09:21
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[1], line 10
#       8         time.sleep(1)
#       9 # 10 dakikalık geri sayım
# ---> 10 countdown_timer(10)
#
# Cell In[1], line 8, in countdown_timer(minutes)
#       6 time_format = f"{mins:02d}:{secs:02d}"
#       7 print(time_format, end='\r', flush=True)
# ----> 8 time.sleep(1)
#
# KeyboardInterrupt:
